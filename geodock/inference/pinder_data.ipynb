# %%
import pandas as pd
import os

# %%
# file_path = "/mnt/disks/pinder-us-east5-a-2023-12-01/index.csv.gz"
# root = "/mnt/disks/pinder-us-east5-a-2023-12-01/pdbs"
# Read the compressed CSV file into a DataFrame
# df = pd.read_csv(file_path, compression='gzip')


root = "/mnt/disks/pinder-us-east5-a-2024-01-09/pdbs"
df = pd.read_csv("/mnt/disks/pinder-us-east5-a-2024-01-09/index.csv.gz", compression='gzip')

# %%
id_values = df['id'].tolist()
id_values

# %%
# Print the column names
column_names = df.columns.tolist()
print("Column Names:", column_names)

pd.set_option('display.max_columns', None)
print("\nFirst 5 Rows:")
df.head()
# pd.reset_option('display.max_columns')
# Out:
# Column Names: ['split', 'id', 'pdb_id', 'cluster_id', 'pinder_s', 'pinder_xl', 'pinder_af2', 'uniprot_R', 'uniprot_L', 'holo_R_pdb', 'holo_L_pdb', 'predicted_R_pdb', 'predicted_L_pdb', 'apo_R_pdb', 'apo_L_pdb', 'apo_R_pdbs', 'apo_L_pdbs', 'holo_R', 'holo_L', 'predicted_R', 'predicted_L', 'apo_R', 'apo_L', 'chain1_neff', 'chain2_neff', 'chain_R', 'chain_L', 'pdb_chain_chain', 'tmp_chain2', 'contains_antibody', 'contains_enzyme', 'affinity_class', 'pKd_pKi_pIC50']
#
# First 5 Rows:
#    split                                id pdb_id         cluster_id  \
# 0  train  117e__A1_P00817--117e__B1_P00817   117e    cluster_587_587
# 1  train  11as__A1_P00963--11as__B1_P00963   11as      cluster_35_35
# 2  train  11ba__A1_P00669--11ba__B1_P00669   11ba  cluster_1410_1410
# 3  train  11bg__A1_P00669--11bg__B1_P00669   11bg  cluster_1410_1410
# 4  train  12as__A1_P00963--12as__B1_P00963   12as      cluster_35_35
#
# ...

# %%
mode = "apo" # apo, predicted

# load only certain test set with subgroup apo/holo/predicted
filtered_df = df[(df['pinder_xl']) & (df[f'{mode}_R']) & (df[f'{mode}_L']) ] #| (df['pinder_af2'] == True)]
# load id of full complex
id_values = filtered_df['id'].tolist()
print(len(id_values))

# load ids of R/L
id_values_R = filtered_df['holo_R_pdb'].tolist()
id_values_L = filtered_df['holo_L_pdb'].tolist()
#print(id_values)

# sanity check that all R/L exist and are in the right order
for index, (id_value, id_R, id_L) in enumerate(zip(id_values, id_values_R, id_values_L)):
    if id_R.replace("-R.pdb","") not in id_value:
        print(f"{id_R} with index {index} does not match")
    # else:
        # print(f"{id_R} with index {index} matches with complex {id_value}")
    if id_L.replace("-L.pdb","") not in id_value:
        print(f"{id_L} with index {index} does not match")       
    # else:
        # print(f"{id_L} with index {index} matches with complex {id_value}")
# Out:
# 401

# %%
for index, (id_value, id_R, id_L) in enumerate(zip(id_values, id_values_R, id_values_L)):
    print(root, id_value, id_R, id_L)

    path_complex = os.path.join(os.path.join(root, id_value + ".pdb"))
    path_receptor = os.path.join(os.path.join(root, id_R))
    path_ligand = os.path.join(os.path.join(root, id_L))
    
    print(os.path.isfile(path_complex), os.path.isfile(path_receptor), os.path.isfile(path_ligand))

# %%
root = "/mnt/disks/pinder-us-east5-a-2023-12-01/pdbs"
# dirs_complexes = [f.path for f in os.scandir(root) if f.is_dir()]

df = pd.read_csv("/mnt/disks/pinder-us-east5-a-2023-12-01/index.csv.gz", compression='gzip')

modes = ["holo", "apo", "predicted"]
pdb_paths = []
modes_decoy = []

for mode in modes:

    # load only certain test set with subgroup apo/holo/predicted
    filtered_df = df[(df['pinder_xl']) & (df[f'{mode}_R']) & (df[f'{mode}_L']) ] #| (df['pinder_af2'] == True)]
    # load id of full complex
    id_values = filtered_df['id'].tolist()
    # load ids of R/L
    id_values_R = filtered_df['holo_R_pdb'].tolist()
    id_values_L = filtered_df['holo_L_pdb'].tolist()
    #print(id_values)

    # sanity check that all R/L exist and are in the right order
    for index, (id_value, id_R, id_L) in enumerate(zip(id_values, id_values_R, id_values_L)):
        if id_R.replace("-R.pdb","") not in id_value:
            print(f"{id_R} with index {index} does not match")
        if id_L.replace("-L.pdb","") not in id_value:
            print(f"{id_L} with index {index} does not match")            

    # list of complex paths
    # dirs_complexes = [f for f in os.listdir(root) if os.path.isdir(os.path.join(root, f))]
    dirs_complexes = [f + ".pdb" for f in id_values if os.path.isdir(os.path.join(root, f))]
    # list of R/L paths
    dirs_receptors = [f for f in id_values_R if os.path.isdir(os.path.join(root, f))]
    dirs_ligands = [f for f in id_values_L if os.path.isdir(os.path.join(root, f))]



    #for d in dirs_complexes:
    for index, (id_value, id_R, id_L) in enumerate(zip(id_values, id_values_R, id_values_L)):

        path_complex = os.path.join(os.path.join(root, id_value + ".pdb"))
        path_receptor = os.path.join(os.path.join(root, id_R))
        path_ligand = os.path.join(os.path.join(root, id_L))

        # check if files exists:
        if not os.path.isfile(path_complex):
            print(f"The file {path_complex} does not exists.")
            continue
        elif not os.path.isfile(path_receptor):
            print(f"The file {path_receptor} does not exists.")
            continue
        elif not os.path.isfile(path_ligand):
            print(f"The file {path_ligand} does not exists.")
            continue
        
        pdb_paths.append((id_value, path_complex, path_receptor, path_ligand))                
        modes_decoy.append((mode, mode))  # For now same mode for both
    print(f"{mode} done. Processed {len(id_values)} complexes.")
print(f" Total number of complexes: {len(pdb_paths)} ")
# Out:
# holo done. Processed 1756 complexes.
# apo done. Processed 401 complexes.
# predicted done. Processed 1575 complexes.
#  Total number of complexes: 3732

# %%
len(df[(df['pinder_s'])])
# Out:
# 117

# %%
import pandas as pd
import os

# %%
df_orig = pd.read_csv("/mnt/disks/pinder-us-east5-a-2024-01-18/index.csv.gz", compression='gzip')

list_saf2 = ['1ex0__A1_P00488--1ex0__B1_P00488',
'1fvf__A1_O62547--1fvf__B1_O62547',
'1qbk__A1_Q92973--1qbk__B1_P62826',
'4ehp__A1_P18206--4ehp__B1_P35221',
'1ex0__A1_P00488--1ex0__B1_P00488',
'4fhm__A1_O36030--4fhm__B1_O43044',
'4gq2__A1_O43044--4gq2__B1_O36030',
'7zvj__A1_O95461--7zvj__B1_O95461',
'7uj4__A1_O00255--7uj4__B1_O00255',
'7xdd__A1_Q9S745--7xdd__B1_Q9SU72',
'7xwe__A1_F4KCC2--7xwe__B1_F4KCC2',
'7zvj__A1_O95461--7zvj__B1_O95461',
'8adb__A1_D6YWY5--8adb__B1_P0CG48',
'8ejm__A1_O43143--8ejm__B1_Q8IWZ8',
'8oik__A1_Q9UPU9--8oik__C1_Q9UPU9',
'8p6k__A1_A0A0H2UWN1--8p6k__B1_A0A0H2UWN1',
'8st7__A1_P0CG48--8st7__D1_A0A2V2RSR1',
'1btk__A1_Q06187--1btk__B1_Q06187',
'1ex0__A1_P00488--1ex0__B1_P00488',
'1fvf__A1_O62547--1fvf__B1_O62547',
'1g3j__A1_P35222--1g3j__B1_P70062',
'1ii6__A1_P52732--1ii6__B1_P52732',
'1jdh__A1_P35222--1jdh__B1_Q9NQB0',
'1nqd__A1_Q9X721--1nqd__B1_Q9X721',
'1nzi__A1_P09871--1nzi__B1_P09871',
'1sr7__A1_P06401--1sr7__B1_P06401',
'1t6b__A1_P13423--1t6b__B1_P58335',
'1wq1__A1_P01112--1wq1__B1_P20936',
'1zhh__A1_P54300--1zhh__B1_P54302',
'1zop__A1_P20701--1zop__B1_P20701',
'2c0l__A1_P50542--2c0l__B1_P22307',
'3oux__A1_Q02248--3oux__B1_P27782',
'3pzd__A1_Q9HD67--3pzd__B1_P70211',
'4e18__A1_P12003--4e18__B1_P26231',
'4ehp__A1_P18206--4ehp__B1_P35221',
'4fhm__A1_O36030--4fhm__B1_O43044',
'4gq2__A1_O43044--4gq2__B1_O36030',
'6e2q__A1_O60674--6e2q__F1_P19235',
'6j0y__A1_P38850--6j0y__B1_Q12098',
'7fn1__A1_P33334--7fn1__B1_P32357',
'1gh7__A1_P32927--1gh7__B1_P32927'
]

list_xl_apoholo = ['1ex0__A1_P00488--1ex0__B1_P00488',
'1fvf__A1_O62547--1fvf__B1_O62547',
'1qbk__A1_Q92973--1qbk__B1_P62826',
'2fsf__A1_P10408--2fsf__B1_P10408',
'2hdi__A1_P17315--2hdi__B1_P06716',
'3a6z__A1_Q9RBY1--3a6z__B1_Q9RBY1',
'4c11__A1_Q6YMS4--4c11__B1_Q6YMS4',
'4ehp__A1_P18206--4ehp__B1_P35221',
'4ol0__A1_P62826--4ol0__B1_Q9Y5L0',
'6j3a__A1_A0A1B1MKD3--6j3a__B2_A0A1B1MKD3',
'6zht__A1_P22515--6zht__B1_P52490',
'6zhu__A1_P14682--6zhu__E1_P22515',
'4rt6__A1_P44602--4rt6__B1_P20058',
'5akp__A1_A0A0H2XCS3--5akp__B1_A0A0H2XCS3',
'1ex0__A1_P00488--1ex0__B1_P00488',
'1nkt__A1_P9WGP5--1nkt__B1_P9WGP5',
'2epn__A1_Q6ST21--2epn__B1_Q6ST21',
'2fsf__A1_P10408--2fsf__B1_P10408',
'3a6z__A1_Q9RBY1--3a6z__B1_Q9RBY1',
'3c7n__A1_P32589--3c7n__B1_P19120',
'3gb8__A1_O14980--3gb8__B1_O95149',
'3v8x__A1_Q9K0U9--3v8x__B1_P02787',
'4c11__A1_Q6YMS4--4c11__B1_Q6YMS4',
'4fhm__A1_O36030--4fhm__B1_O43044',
'4gq2__A1_O43044--4gq2__B1_O36030',
'4hg6__A1_Q3J125--4hg6__B1_Q3J126',
'4ia6__A1_Q5FL96--4ia6__B1_Q5FL96',
'4m8m__A1_Q5RGW1--4m8m__B1_Q5RGW1',
'4nfu__A1_Q9XF23--4nfu__B1_Q4F883',
'4ok4__A1_Q21FJ0--4ok4__B1_Q21FJ0',
'4ol0__A1_P62826--4ol0__B1_Q9Y5L0',
'4q86__A1_P75838--4q86__B1_P75838',
'4u3e__A1_Q9WYL6--4u3e__B1_Q9WYL6',
'4yzw__A1_Q8MZM3--4yzw__B1_Q8MZM3',
'5c05__A1_A0A0M3Q1Q3--5c05__B1_A0A0M3Q1Q3',
'5dgq__A1_Q6LUT2--5dgq__B1_Q6LUT2',
'5kyy__A1_Q15436--5kyy__B1_O94855',
'5of9__A1_Q9Y6X9--5of9__B1_Q9Y6X9',
'5t3r__A1_Q8A6W4--5t3r__B1_Q8A6W3',
'5x6x__A1_P14583--5x6x__D1_P14583',
'5zq2__A1_Q6BBR6--5zq2__B1_Q6BBR6',
'6i7s__A1_P07237--6i7s__C1_P55157',
'6j3a__A1_A0A1B1MKD3--6j3a__B2_A0A1B1MKD3',
'6jxh__A1_P19156--6jxh__B1_P18434',
'6zhu__A1_P14682--6zhu__E1_P22515',
'7bjt__A1_G0LCA3--7bjt__B1_G0LCA3',
'7d8n__A1_Q9ULW8--7d8n__B1_Q9ULW8',
'7kaz__A1_A0A0D6GJV1--7kaz__C1_A0A0D6GJV1',
'7vyj__A1_Q84G19--7vyj__B1_Q84G19',
'5akp__A1_A0A0H2XCS3--5akp__B1_A0A0H2XCS3',
'8sbc__A1_P42336--8sbc__B1_P27986'
]

df_cpu = df_orig[df_orig['id'].isin(list_xl_apoholo)].reset_index()

# %%
df_cpu

# %%
df_cpu.to_csv('/home/celine/geodock_inference_240124/index_xl_apoholo_cpu_seqs.csv', index=False)

# %%
input_path = '/home/celine/geodock_inference_240124/errors_xl_pred.txt'
output_path = '/home/celine/geodock_inference_240124/cpu_rerun_xl_pred.txt'

with open(input_path, 'r') as input_file, open(output_path, 'w') as output_file:
    for line in input_file:
        if 'CUDA' not in line:
            output_file.write(line)
            print(line)  # .strip() removes leading and trailing whitespaces (including newline characters)

# %%
pred_ids = '/home/celine/geodock_inference_240124/cpu_rerun_xl_pred.txt'

with open(pred_ids, 'r') as text_file:
    list_xl_pred = [line.strip() for line in text_file.readlines()]

# %%
# len(list_xl_pred)
df_cpu = df_orig[df_orig['id'].isin(list_xl_pred)].reset_index()
df_cpu.to_csv('/home/celine/geodock_inference_240124/index_xl_pred_cpu_seqs.csv', index=False)

# %%
len(list_xl_pred)
# Out:
# 312

# %%
# stats in idx file

df_ps = df_orig[df_orig['pinder_s']==True].reset_index()
df_af2 = df_orig[df_orig['pinder_af2']==True].reset_index()
df_xl = df_orig[df_orig['pinder_xl']==True].reset_index()

# %%
df_ps['apo_L'].value_counts().get(True, 0)
# Out:
# 68

# %%
modes = ['apo', 'holo', 'predicted']
testset = ['pinder_xl', 'pinder_af2', 'pinder_s']
for t in testset:
    print(t)
    for m in modes:
        print(m)
        print(len(df_orig[(df_orig[t]) & (df_orig[f'{m}_R']) & (df_orig[f'{m}_L']) ]))
# Out:
# pinder_xl
# apo
# 277
# holo
# 1455
# predicted
# 1296
# pinder_af2
# apo
# 15
# holo
# 69
# predicted
# 50
# pinder_s
# apo
# 52
# holo
# 101
# predicted
# 90

# %%
df_xl.columns
# Out:
# Index(['index', 'pdb_id', 'chain_R', 'chain_L', 'split', 'id', 'cluster_id',
#        'pinder_s', 'pinder_xl', 'pinder_af2', 'uniprot_R', 'uniprot_L',
#        'holo_R_pdb', 'holo_L_pdb', 'predicted_R_pdb', 'predicted_L_pdb',
#        'apo_R_pdb', 'apo_L_pdb', 'apo_R_pdbs', 'apo_L_pdbs', 'holo_R',
#        'holo_L', 'predicted_R', 'predicted_L', 'apo_R', 'apo_L', 'chain1_neff',
#        'chain2_neff', 'pdb_chain_chain', 'contains_enzyme', 'affinity_class',
#        'pKd_pKi_pIC50', 'contains_antibody'],
#       dtype='object')

# %%
target_path = '/home/celine/geodock_inference_240124/'

# all ids exists
modes = ['apo', 'holo', 'predicted']
testset = ['pinder_xl', 'pinder_af2', 'pinder_s']

for t in testset:
    for m in modes:
        subset = df_orig[(df_orig[t]) & (df_orig[f'{m}_R']) & (df_orig[f'{m}_L']) ]
        for idx, row in subset.iterrows():
            # print(row['id'])
            check_folder = os.path.join(target_path, row['id'], m +'_decoys', )
            check_file = os.path.join(target_path, row['id'], m +'_decoys', 'model_1.pdb')

            if not os.path.exists(check_file):
                print(f'{check_file} from {t,m} does not exists')
            # else:
                # print(f'{check_file} from {t} exists')

# %%
df_orig[(df_orig['pinder_af2'])]
# Out:
#        pdb_id chain_R chain_L split                                        id  \
# 1320     7tdq      A1      B1  test          7tdq__A1_Q2HR80--7tdq__B1_Q2HR80
# 1321     7tvh      A1      B1  test          7tvh__A1_Q9I2Q1--7tvh__B1_Q9I2Q1
# 1322     7tvm      A1      B1  test    7tvm__A1_UNDEFINED--7tvm__B1_UNDEFINED
# 1327     7uav      A1      B1  test          7uav__A1_P0DW58--7uav__B1_P0DW58
# 1328     7ubj      A1      B1  test          7ubj__A1_P03047--7ubj__B1_P03047
# ...       ...     ...     ...   ...                                       ...
# 1429     8p6k      A1      B1  test  8p6k__A1_A0A0H2UWN1--8p6k__B1_A0A0H2UWN1
# 1430     8pq7      A1      B1  test          8pq7__A1_M1C5B8--8pq7__B1_D0N0Z8
# 1431     8st7      A1      D1  test      8st7__A1_P0CG48--8st7__D1_A0A2V2RSR1
# 1433     8u0g      A1      B1  test          8u0g__A1_Q9RYE6--8u0g__B1_Q9RYE6
# 239365   7wr3      A1      C1  test          7wr3__A1_P0AEX9--7wr3__C1_P0DP23
#
# ...
